# %% [markdown]
# ##GPU检测

# %%
# !nvidia-smi
# Out:
# Sat Mar 18 06:15:56 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P0    25W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# ##克隆 webui 仓库、下载依赖

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui /content/stable-diffusion-webui
# %cd /content/stable-diffusion-webui
# Out:
# Cloning into '/content/stable-diffusion-webui'...
# remote: Enumerating objects: 17106, done.
# remote: Total 17106 (delta 0), reused 0 (delta 0), pack-reused 17106
# Receiving objects: 100% (17106/17106), 27.84 MiB | 13.65 MiB/s, done.
# Resolving deltas: 100% (11953/11953), done.
# /content/stable-diffusion-webui

# %%
# !pip install -r requirements.txt


from IPython.display import clear_output
import ipywidgets as widgets

def inf(msg, style, width):
  layout = widgets.Layout(min_width=width) 
  inf = widgets.Button(description=msg, disabled=True, button_style=style, layout=layout);
  display(inf)

# 清除输出、显示块
clear_output()
inf('\u2714 Done','success', '50px')
# Out:
# Button(button_style='success', description='✔ Done', disabled=True, layout=Layout(min_width='50px'), style=But…

# %% [markdown]
# ##下载 Huggingface 模型

# %%
user_token = "" #@param {type:"string"}
user_header = f"\"Authorization: Bearer {user_token}\""

# 模型地址
model_url = "https://huggingface.co/prompthero/openjourney/resolve/main/mdjrny-v4.ckpt" #@param {type:"string"}

#@markdown ###更多模型地址
#@markdown - GuoFeng3.t：https://huggingface.co/xiaolxl/GuoFeng3/resolve/main/GuoFeng3.2.ckpt
#@markdown - Envvi/Inkpunk-Diffusion（头像庞克风）：https://huggingface.co/Envvi/Inkpunk-Diffusion/resolve/main/Inkpunk-Diffusion-v2.ckpt
#@markdown - prompthero/openjourney（Midjourney v4 风格）：https://huggingface.co/prompthero/openjourney/resolve/main/mdjrny-v4.ckpt

# 下载
# !echo $model_url
# !wget --header={user_header} $model_url -O models/model.ckpt

# %% [markdown]
# ##运行

# %%
#@title 配置

#生成公开链接
need_share = True

#@markdown 生成公开链接，可以设置访问授权信息
account = "" #@param {type:"string"}
password = "" #@param {type:"string"}


share=''
if need_share:
  share='--share'

auth=f"--gradio-auth {account}:{password}"
if account =="" or password=="":
  auth=""

# %%
# !COMMANDLINE_ARGS="--gradio-debug --share $auth" python launch.py
